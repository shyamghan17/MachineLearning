# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Copyright by Pierian Data Inc.</em></center>
# <center><em>For more information, visit us at <a href='http://www.pieriandata.com'>www.pieriandata.com</a></em></center>

# %% [markdown]
# # K Means Color Quantization

# %% [markdown]
# ### Imports

# %%
import numpy as np

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %% [markdown]
# ### The Image

# %%
image_as_array = mpimg.imread('../DATA/palm_trees.jpg')

# %%
image_as_array # RGB CODES FOR EACH PIXEL
# Out:
# array([[[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 23,  63,  99],
#         [ 51,  91, 127],
#         [ 50,  90, 126]],
#
#        [[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 31,  71, 107],
#         [ 48,  88, 124],
#         [ 47,  90, 125]],
#
#        [[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 39,  79, 115],
#         [ 42,  85, 120],
#         [ 44,  88, 123]],
#
#        ...,
#
#        [[  4,   4,   6],
#         [  4,   4,   6],
#         [  4,   4,   6],
#         ...,
#         [  9,   9,  11],
#         [  9,   9,  11],
#         [  9,   9,  11]],
#
#        [[  3,   3,   5],
#         [  3,   3,   5],
#         [  3,   3,   5],
#         ...,
#         [  8,   8,  10],
#         [  8,   8,  10],
#         [  8,   8,  10]],
#
#        [[  4,   4,   6],
#         [  4,   4,   6],
#         [  4,   4,   6],
#         ...,
#         [  9,   9,  11],
#         [ 10,  10,  12],
#         [ 10,  10,  12]]], dtype=uint8)

# %%
plt.figure(figsize=(6,6),dpi=200)
plt.imshow(image_as_array)

# %% [markdown]
# ## Using Kmeans to Quantize Colors
#
# Quantizing colors means we'll reduce the number of unique colors here to K unique colors. Let's try just 6 colors!

# %%
image_as_array.shape
# (h,w,3 color channels)
# Out:
# (1401, 934, 3)

# %% [markdown]
# ### Convert from 3d to 2d
#
# Kmeans is designed to train on 2D data (data rows and feature columns), so we can reshape the above strip by using (h,w,c) ---> (h * w,c)

# %%
(h,w,c) = image_as_array.shape

# %%
image_as_array2d = image_as_array.reshape(h*w,c)

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=8)

# %%
model
# Out:
# KMeans()

# %%
labels = model.fit_predict(image_as_array2d)

# %%
labels
# Out:
# array([4, 4, 4, ..., 1, 1, 1], dtype=int32)

# %%
# THESE ARE THE 6 RGB COLOR CODES!
model.cluster_centers_
# Out:
# array([[100.9236648 , 129.07698562, 146.94053866],
#        [  2.27664862,   2.0129613 ,   3.02518303],
#        [201.3432072 , 154.27564582,  97.61666845],
#        [ 38.75541667,  43.85251984,  51.63303571],
#        [ 58.46408057,  98.28290007, 129.90952942],
#        [155.57533992, 149.90008457, 138.59254128],
#        [224.18331203, 134.65220221,  40.00003486],
#        [107.85000366,  77.34606281,  60.01749591]])

# %%
rgb_codes = model.cluster_centers_.round(0).astype(int)

# %%
rgb_codes
# Out:
# array([[101, 129, 147],
#        [  2,   2,   3],
#        [201, 154,  98],
#        [ 39,  44,  52],
#        [ 58,  98, 130],
#        [156, 150, 139],
#        [224, 135,  40],
#        [108,  77,  60]])

# %%
quantized_image = np.reshape(rgb_codes[labels], (h, w, c))

# %%
quantized_image
# Out:
# array([[[ 58,  98, 130],
#         [ 58,  98, 130],
#         [ 58,  98, 130],
#         ...,
#         [ 39,  44,  52],
#         [ 58,  98, 130],
#         [ 58,  98, 130]],
#
#        [[ 58,  98, 130],
#         [ 58,  98, 130],
#         [ 58,  98, 130],
#         ...,
#         [ 58,  98, 130],
#         [ 58,  98, 130],
#         [ 58,  98, 130]],
#
#        [[ 58,  98, 130],
#         [ 58,  98, 130],
#         [ 58,  98, 130],
#         ...,
#         [ 58,  98, 130],
#         [ 58,  98, 130],
#         [ 58,  98, 130]],
#
#        ...,
#
#        [[  2,   2,   3],
#         [  2,   2,   3],
#         [  2,   2,   3],
#         ...,
#         [  2,   2,   3],
#         [  2,   2,   3],
#         [  2,   2,   3]],
#
#        [[  2,   2,   3],
#         [  2,   2,   3],
#         [  2,   2,   3],
#         ...,
#         [  2,   2,   3],
#         [  2,   2,   3],
#         [  2,   2,   3]],
#
#        [[  2,   2,   3],
#         [  2,   2,   3],
#         [  2,   2,   3],
#         ...,
#         [  2,   2,   3],
#         [  2,   2,   3],
#         [  2,   2,   3]]])

# %%
plt.figure(figsize=(6,6),dpi=200)
plt.imshow(quantized_image)
